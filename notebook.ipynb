# %%
import pandas as pd

# %%
df = pd.read_csv("./dataset/HIST_PAINEL_COVIDBR_13mai2021.csv", sep=";")

# %%
df
# Out:
#                regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 0              Brasil    NaN       NaN     76       NaN             NaN
# 1              Brasil    NaN       NaN     76       NaN             NaN
# 2              Brasil    NaN       NaN     76       NaN             NaN
# 3              Brasil    NaN       NaN     76       NaN             NaN
# 4              Brasil    NaN       NaN     76       NaN             NaN
# ...               ...    ...       ...    ...       ...             ...
# 2321512  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2321513  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2321514  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2321515  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 2321516  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#           nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# ...

# %%
df_states = df[(~df["estado"].isna()) & (df["codmun"].isna())]

# %%
df_states
# Out:
#              regiao estado municipio  coduf  codmun  codRegiaoSaude  \
# 446           Norte     RO       NaN     11     NaN             NaN
# 447           Norte     RO       NaN     11     NaN             NaN
# 448           Norte     RO       NaN     11     NaN             NaN
# 449           Norte     RO       NaN     11     NaN             NaN
# 450           Norte     RO       NaN     11     NaN             NaN
# ...             ...    ...       ...    ...     ...             ...
# 12429  Centro-Oeste     DF       NaN     53     NaN             NaN
# 12430  Centro-Oeste     DF       NaN     53     NaN             NaN
# 12431  Centro-Oeste     DF       NaN     53     NaN             NaN
# 12432  Centro-Oeste     DF       NaN     53     NaN             NaN
# 12433  Centro-Oeste     DF       NaN     53     NaN             NaN
#
#       nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  \
# 446               NaN  2020-02-25          9         1777225.0
# ...

# %%
df_brasil = df[df["regiao"] == "Brasil"]

# %%
df_brasil
# Out:
#      regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3    Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4    Brasil    NaN       NaN     76     NaN             NaN             NaN
# ..      ...    ...       ...    ...     ...             ...             ...
# 441  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 442  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 443  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 444  Brasil    NaN       NaN     76     NaN             NaN             NaN
# 445  Brasil    NaN       NaN     76     NaN             NaN             NaN
#
# ...

# %%
df_brasil.to_csv("./dataset/df_brasil.csv")
df_states.to_csv("./dataset/df_states.csv")
